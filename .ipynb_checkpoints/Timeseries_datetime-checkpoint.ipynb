# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.4.3-cp39-cp39-win_amd64.whl (10.6 MB)
# Collecting numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10"
#   Downloading numpy-1.23.2-cp39-cp39-win_amd64.whl (14.7 MB)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\hedranovich\repos\class.projects\ve\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\hedranovich\repos\class.projects\ve\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: numpy, pytz, pandas
# Successfully installed numpy-1.23.2 pandas-1.4.3 pytz-2022.2.1
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'd:\hedranovich\repos\class.projects\ve\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'd:\hedranovich\repos\class.projects\ve\scripts\python.exe -m pip install --upgrade pip' command.
#   Downloading matplotlib-3.5.3-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.36.0-py3-none-any.whl (950 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\hedranovich\repos\class.projects\ve\lib\site-packages (from matplotlib) (3.0.9)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: numpy>=1.17 in d:\hedranovich\repos\class.projects\ve\lib\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\hedranovich\repos\class.projects\ve\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\hedranovich\repos\class.projects\ve\lib\site-packages (from matplotlib) (21.3)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp39-cp39-win_amd64.whl (3.3 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in d:\hedranovich\repos\class.projects\ve\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: fonttools, kiwisolver, pillow, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.36.0 kiwisolver-1.4.4 matplotlib-3.5.3 pillow-9.2.0

# %%
import matplotlib as plt

# %%
import ftplib

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')

# %%
df
# Out:
#               ds          y
# 0     2007-12-10   9.590761
# 1     2007-12-11   8.519590
# 2     2007-12-12   8.183677
# 3     2007-12-13   8.072467
# 4     2007-12-14   7.893572
# ...          ...        ...
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374
#
# [2905 rows x 2 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# ds     object
# y     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2905 entries, 0 to 2904
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      2905 non-null   object
#  1   y       2905 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 45.5+ KB

# %%
df['date'] = pd.to_datetime(df['ds'])

# %%
df.dtypes
# Out:
# ds              object
# y              float64
# date    datetime64[ns]
# dtype: object

# %%
time = df['date']

# %%
time.dt.year
# Out:
# 0       2007
# 1       2007
# 2       2007
# 3       2007
# 4       2007
#         ...
# 2900    2016
# 2901    2016
# 2902    2016
# 2903    2016
# 2904    2016
# Name: date, Length: 2905, dtype: int64

# %%
time.dt.year.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.quarter
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 2900    1
# 2901    1
# 2902    1
# 2903    1
# 2904    1
# Name: date, Length: 2905, dtype: int64

# %%
time.dt.quarter.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.month
# Out:
# 0       12
# 1       12
# 2       12
# 3       12
# 4       12
#         ..
# 2900     1
# 2901     1
# 2902     1
# 2903     1
# 2904     1
# Name: date, Length: 2905, dtype: int64

# %%
time.dt.month.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.week
# Out:
# C:\Users\st\AppData\Local\Temp\ipykernel_10932\521545131.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   time.dt.week
# 0       50
# 1       50
# 2       50
# 3       50
# 4       50
#         ..
# 2900     2
# 2901     2
# 2902     3
# 2903     3
# 2904     3
# Name: date, Length: 2905, dtype: int64

# %%
time.dt.week.hist()
# Out:
# C:\Users\st\AppData\Local\Temp\ipykernel_10932\2562023697.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   time.dt.week.hist()
# <AxesSubplot:>

# %%
time.dt.weekday
# Out:
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
#        ..
# 2900    5
# 2901    6
# 2902    0
# 2903    1
# 2904    2
# Name: date, Length: 2905, dtype: int64

# %%
time.dt.weekday.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.day_name()
# Out:
# 0          Monday
# 1         Tuesday
# 2       Wednesday
# 3        Thursday
# 4          Friday
#           ...
# 2900     Saturday
# 2901       Sunday
# 2902       Monday
# 2903      Tuesday
# 2904    Wednesday
# Name: date, Length: 2905, dtype: object

# %%
time.dt.day_name().hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.hour
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2900    0
# 2901    0
# 2902    0
# 2903    0
# 2904    0
# Name: date, Length: 2905, dtype: int64

# %%
time.dt.hour.value_counts()
# Out:
# 0    2905
# Name: date, dtype: int64

# %%
time.dt.hour.hist()
# Out:
# <AxesSubplot:>

# %%
value = df['y']

# %%
value.hist()
# Out:
# <AxesSubplot:>

# %%
cd = df.copy()

# %%
cd.index
# Out:
# RangeIndex(start=0, stop=2905, step=1)

# %%
cd.columns
# Out:
# Index(['ds', 'y', 'date'], dtype='object')

# %%
cd.index = cd['date']

# %%
cd.drop(['ds', 'date'], axis = 1, inplace= True)

# %%
cd.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
time.diff(1)
# Out:
# 0         NaT
# 1      1 days
# 2      1 days
# 3      1 days
# 4      1 days
#         ...
# 2900   1 days
# 2901   1 days
# 2902   1 days
# 2903   1 days
# 2904   1 days
# Name: date, Length: 2905, dtype: timedelta64[ns]

# %%
diff_time = time.diff(1).dropna()

# %%
diff_time
# Out:
# 1      1 days
# 2      1 days
# 3      1 days
# 4      1 days
# 5      1 days
#         ...
# 2900   1 days
# 2901   1 days
# 2902   1 days
# 2903   1 days
# 2904   1 days
# Name: date, Length: 2904, dtype: timedelta64[ns]

# %%
diff_time.value_counts()
# Out:
# 1 days     2875
# 2 days       20
# 3 days        5
# 4 days        2
# 20 days       1
# 5 days        1
# Name: date, dtype: int64

# %%
diff_time.plot()
# Out:
# <AxesSubplot:>

# %%
diff_time
# Out:
# 1      1 days
# 2      1 days
# 3      1 days
# 4      1 days
# 5      1 days
#         ...
# 2900   1 days
# 2901   1 days
# 2902   1 days
# 2903   1 days
# 2904   1 days
# Name: date, Length: 2904, dtype: timedelta64[ns]

# %%
dy = cd.diff(1).fillna(0)

# %%
dy.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dy.mean()
# Out:
# y   -0.000241
# dtype: float64

# %%
dy.std()
# Out:
# y    0.48998
# dtype: float64

# %%
dy.hist(bins = 50)
# Out:
# array([[<AxesSubplot:title={'center':'y'}>]], dtype=object)

# %%
cd.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
cd.describe()
# Out:
#                  y
# count  2905.000000
# mean      8.138958
# std       0.845957
# min       5.262690
# 25%       7.514800
# 50%       7.997999
# 75%       8.580168
# max      12.846747

# %%
period = 7 #days
period = 30 #days
period = 365 #days
period = 2*365 #days

# %%
rd = cd.rolling(period).mean().dropna()

# %%
rd
# Out:
#                    y
# date
# 2007-12-10       NaN
# 2007-12-11       NaN
# 2007-12-12       NaN
# 2007-12-13       NaN
# 2007-12-14       NaN
# ...              ...
# 2016-01-16  8.116764
# 2016-01-17  8.258500
# 2016-01-18  8.524649
# 2016-01-19  8.666195
# 2016-01-20  8.783941
#
# [2905 rows x 1 columns]

# %%
rd.plot()
plt.title(period);

# %%
rd.plot()
plt.title(period);

# %%
import matplotlib.pyplot as plt

# %%
rd.plot()
plt.title(period);

# %%
rd.plot()
plt.title(period);

# %%
rd = cd.rolling(period).sum().dropna()
rd.plot()
plt.title(period);

# %%
ed = cd.expanding(7).mean()
ed.plot()
plt.title(7);

# %%
ed = cd.expanding(30).mean()
ed.plot()
plt.title(30);

# %%
ed = cd.expanding(365).mean()
ed.plot()
plt.title(365);

# %%
ed = cd.expanding(1).mean()
ed.plot()
plt.title(1);
